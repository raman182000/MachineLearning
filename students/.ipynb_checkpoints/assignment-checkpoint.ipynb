# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("StudentsPerformance.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
sns.set_palette("winter_r")

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
sns.palplot(sns.color_palette('winter_r'))

# %%
plt.figure(figsize=(8,7))
sns.countplot(data['gender'])
plt.title('Gender Diagram',fontdict={'fontsize':14})
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Raman\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
labels=data['gender'].value_counts().index.tolist()
values=data['gender'].value_counts().tolist()
plt.figure(figsize=(8,8))
plt.pie(x=values,labels=labels,autopct="%1.2f%%",shadow=True)
plt.show()

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize=(8,7))
sns.countplot(data['race/ethnicity'])
plt.title('race/ethnicity Diagram',fontdict={'fontsize':14})
plt.xlabel('race/ethnicity')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Raman\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
labels=data['race/ethnicity'].value_counts().index.tolist()
values=data['race/ethnicity'].value_counts().tolist()
plt.figure(figsize=(8,8))
plt.pie(x=values,labels=labels,autopct="%1.2f%%",shadow=True)
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.countplot(data['parental level of education'])
plt.title('parental level of education Diagram',fontdict={'fontsize':14})
plt.xlabel('parental level of education')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Raman\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
labels=data['parental level of education'].value_counts().index.tolist()
values=data['parental level of education'].value_counts().tolist()
plt.figure(figsize=(8,8))
plt.pie(x=values,labels=labels,autopct="%1.2f%%",shadow=True)
plt.show()

# %%
plt.figure(figsize=(8,7))
sns.countplot(data['lunch'])
plt.title('lunch Diagram',fontdict={'fontsize':14})
plt.xlabel('lunch')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Raman\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
labels=data['lunch'].value_counts().index.tolist()
values=data['lunch'].value_counts().tolist()
plt.figure(figsize=(8,8))
plt.pie(x=values,labels=labels,autopct="%1.2f%%",shadow=True)
plt.show()
